# %% [markdown]
# # Log-transform target

# %%
import numpy as np

y_train_log = np.log1p(y_train)
y_valid_log = np.log1p(y_valid)

pipeline.fit(X_train, y_train_log)
pred_valid = np.expm1(pipeline.predict(X_valid))
